# %% [markdown]
# # sklearn library
#
# ## 1. Functions
#
# - `fit(X, y)` $-$ Training the model on the data
# - `score(X, y)` $-$ Evaluate the model
# - `predict(X)` $-$ Used the model

# %%
import numpy as np
import matplotlib.pyplot as plt

# dataset
np.random.seed(0)
m = 100 # number of samples
X = np.linspace(0, 10, m).reshape((m, 1))
y = X + np.random.randn(m, 1)

# plot data
_ = plt.scatter(X, y)

# %%
from sklearn.linear_model import LinearRegression

# %%
# Create a linear model
model = LinearRegression()

# Training the model on the data
model.fit(X, y)

# Evaluate the model 
model.score(X, y) # Coefficient of determination
# Out:
# 0.8881140743377214

# %%
# Calcul the predicted labels y
y_predict = model.predict(X)

# plot data
plt.scatter(X, y)

# plot result
plt.plot(X, y_predict, c="r", linewidth=4)

# %% [markdown]
# <br>
#
# ## Nonlinear example

# %%
import numpy as np
import matplotlib.pyplot as plt

# Dataset
np.random.seed(0)
m = 100 # number of samples
X = np.linspace(0, 10, m).reshape((m, 1))
y = X ** 2 + np.random.randn(m, 1)

# plot data
_ = plt.scatter(X, y)

# %%
from sklearn.svm import SVR

# %%
# Create a nonlinear model
model = SVR(C=100)

# Training the model on the data
model.fit(X, y.reshape(m, ))

# Evaluate the model 
model.score(X, y) # Coefficient of determination
# Out:
# 0.9989763625652847

# %%
# Calcul the predicted labels y
y_predict = model.predict(X)

# plot data
plt.scatter(X, y)

# plot result
plt.plot(X, y_predict, c="r", linewidth=4)
